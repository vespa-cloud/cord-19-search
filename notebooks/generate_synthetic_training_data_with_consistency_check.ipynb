# %% [markdown]
# ## Consistency check of synthetic queries
#
# This notebook uses the synthetic queries generated by generate_synthetic_data_using_t5.ipynb and generates
# training data.

# %%
# !pip3 install --upgrade pandas requests transformers pyarrow
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.10/site-packages (2.28.2)
# Requirement already satisfied: transformers in /opt/homebrew/lib/python3.10/site-packages (4.25.1)
# Collecting transformers
#   Downloading transformers-4.26.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 22.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyarrow in /opt/homebrew/lib/python3.10/site-packages (10.0.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /opt/homebrew/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests) (1.26.13)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /opt/homebrew/lib/python3.10/site-packages (from transformers) (0.11.1)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.10/site-packages (from transformers) (3.8.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/homebrew/lib/python3.10/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/lib/python3.10/site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/lib/python3.10/site-packages (from transformers) (5.4.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/homebrew/lib/python3.10/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.25.1
#     Uninstalling transformers-4.25.1:
#       Successfully uninstalled transformers-4.25.1
# Successfully installed transformers-4.26.0

# %%
import pandas as pd
import torch

# %%
queries = pd.read_csv('trec-covid-queries.tsv', delimiter='\t', names=['id','query'])

# %%
queries
# Out:
#              id                                              query
# 0      5p68npdb  query: what is the name of the virus that caus...
# 1      pd1g119c  query: what is the title of the abstract that ...
# 2      y5gmlsi1  query: what tyrosine kinases are involved in d...
# 3      7o1hprbe  query: what is the research activity on probio...
# 4      rbrjlz25  query: What is the effect of climate change on...
# ...         ...                                                ...
# 33095  kcfhnvqg  query: what is the best surgical treatment for...
# 33096  v4wre1qk  query: what is the agent based modeling of the...
# 33097  2v4izbiq  query: what is the name of the virus that caus...
# 33098  y6jnbp81  query: what is the vascular integrity of the a...
# 33099  hje6lzip  query: what is the learning curve of a young s...
#
# [33100 rows x 2 columns]

# %%
queries['clean_query'] = queries['query'].apply(lambda x: x.lower().replace('query:','').strip())

# %%
queries
# Out:
#              id                                              query  \
# 0      5p68npdb  query: what is the name of the virus that caus...
# 1      pd1g119c  query: what is the title of the abstract that ...
# 2      y5gmlsi1  query: what tyrosine kinases are involved in d...
# 3      7o1hprbe  query: what is the research activity on probio...
# 4      rbrjlz25  query: What is the effect of climate change on...
# ...         ...                                                ...
# 33095  kcfhnvqg  query: what is the best surgical treatment for...
# 33096  v4wre1qk  query: what is the agent based modeling of the...
# 33097  2v4izbiq  query: what is the name of the virus that caus...
# 33098  y6jnbp81  query: what is the vascular integrity of the a...
# 33099  hje6lzip  query: what is the learning curve of a young s...
#
#                                              clean_query
# 0      what is the name of the virus that caused resp...
# 1      what is the title of the abstract that is titl...
# 2      what tyrosine kinases are involved in dengue v...
# 3      what is the research activity on probiotics in...
# 4      what is the effect of climate change on human ...
# ...                                                  ...
# 33095  what is the best surgical treatment for adenoc...
# 33096  what is the agent based modeling of the spread...
# 33097  what is the name of the virus that caused the ...
# 33098  what is the vascular integrity of the arterial...
# 33099  what is the learning curve of a young surgeon'...
#
# [33100 rows x 3 columns]

# %%
import numpy as np

# %% [markdown]
# The following queries the index using the generated synthetic query. If the query does not retrieve
# the document that generated the query in position 0, the query is discared and filtered out.
#
# If the query is retrieving the document at position 0, we sample 2 other documents among the top 100 hits
# as negatives.

# %%
def search(row):
    query = row['clean_query']
    doc_id = row['id']
    query_request = {
        'yql': 'select title, abstract, matchfeatures, cord_uid from doc where {"grammar":"tokenize", "targetHits":200}userInput(@query)',
        'query': query, 
        'ranking': 'hybrid-colbert',
        'bolding': 'false',
        'hits' : 100,  
        'language' : 'en', 
        'timeout' : '20s',
        'summary': 'short'
    }
    try:
        response = session.post("http://localhost:8080/search/", json=query_request,timeout=120)
    except:
        response = session.post("http://localhost:8080/search/", json=query_request,timeout=120)
    if response.ok:
        json_result = response.json()
        root = json_result['root']
        total_count = root['fields']['totalCount']
        
        positive_pairs = []
        negative_pairs = []
        
        if total_count > 0:
          pos = 0
          for hit in root['children']:
            id = hit['fields'].get('cord_uid')
            if id is None:
              continue
            relevant = False
            if id == doc_id and pos < 1:
              relevant = True
            title = hit['fields'].get('title')
            abstract = hit['fields'].get('abstract')
            relevance = hit['relevance']
            bm25 = hit['fields']['matchfeatures']['bm25']
            colbert = hit['fields']['matchfeatures']['colbert_maxsim']
            doc = {
              "query": query,
              "doc_id": id,
              "relevant": relevant,
              "title": title,
              "abstract": abstract,
              "score": relevance,
              "bm25": bm25,
              "colbert": colbert
            }
            pos = pos + 1
            if relevant:
              positive_pairs.append(doc)
            else:
              negative_pairs.append(doc)
        if len(positive_pairs) > 0:
          responses.append(positive_pairs[0])
          for n in np.random.choice(negative_pairs, size=2):
            responses.append(n)
          
    else:
      print("query request failed with " + str(response.json()))

# %%
import json
import requests
from requests.adapters import HTTPAdapter, Retry

# %%
global session
session = requests.Session()
retries = Retry(total=20, connect=20,
      backoff_factor=0.3,
      status_forcelist=[ 500, 503, 504, 429 ]
)
session.mount('https://', HTTPAdapter(max_retries=retries))
session.mount('http://', HTTPAdapter(max_retries=retries))

# %%
global responses
responses = []

# %%
queries.apply(search,axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 33095    None
# 33096    None
# 33097    None
# 33098    None
# 33099    None
# Length: 33100, dtype: object

# %%
df_result = pd.DataFrame.from_records(responses)

# %%
df_result
# Out:
#                                                    query    doc_id  relevant  \
# 0      what is the name of the virus that caused resp...  5p68npdb      True
# 1      what is the name of the virus that caused resp...  9x2z2hg1     False
# 2      what is the name of the virus that caused resp...  0qdjk7e0     False
# 3      what tyrosine kinases are involved in dengue v...  y5gmlsi1      True
# 4      what tyrosine kinases are involved in dengue v...  1cd27vgj     False
# ...                                                  ...       ...       ...
# 42463  what is the vascular integrity of the arterial...  d8pf9s3k     False
# 42464  what is the vascular integrity of the arterial...  42vglg9p     False
# 42465  what is the learning curve of a young surgeon'...  hje6lzip      True
# 42466  what is the learning curve of a young surgeon'...  g0clai34     False
# 42467  what is the learning curve of a young surgeon'...  rw7edqri     False
#
#                                                    title  \
# 0      Influenza A (H10N7) Virus Causes Respiratory T...
# 1      Human bocavirus infection as a cause of severe...
# 2      Respiratory syncytial virus and human rhinovir...
# 3      Identification and characterization of the rol...
# 4      Intrahost selection pressures drive rapid deng...
# ...                                                  ...
# 42463  Influence of Thrombus Composition on Thrombect...
# 42464  Fibrin Clot Architecture in Acute Ischemic Str...
# 42465  Learning Curve of a Young Surgeon's Video-assi...
# 42466  Video-assisted thoracic surgery right sleeve l...
# 42467  Transumbilical laparoendoscopic single-site su...
#
#                                                 abstract     score  \
# 0      Avian influenza viruses sporadically cross the...  0.857566
# 1      Abstract In 2005 human bocavirus (HBoV) was di...  0.440396
# 2      Respiratory infections are very common in Kuwa...  0.442540
# 3      We screened a siRNA library targeting human ty...  0.925027
# 4      Dengue, caused by four dengue virus serotypes ...  0.494465
# ...                                                  ...       ...
# 42463  PURPOSE A first-pass, direct aspiration techni...  0.599344
# 42464  BACKGROUND The composition of intra-arterial c...  0.615178
# 42465  BACKGROUND The purpose of this paper is to pre...  0.944653
# 42466  A 50-year-old active male with a smoking histo...  0.553823
# 42467  PURPOSE The aim is to report our 1-year experi...  0.530737
#
#              bm25    colbert
# 0       76.120982  72.329134
# 1       26.244967  59.373533
# 2       28.187150  57.838307
# 3       53.349261  82.207237
# 4       22.794240  58.499635
# ...           ...        ...
# 42463   43.753466  59.496343
# 42464   43.899136  61.735330
# 42465  109.730832  77.457502
# 42466   52.099838  57.593029
# 42467   32.831907  67.617608
#
# [42468 rows x 8 columns]

# %%
df_result.to_parquet("train_data_k1.parquet")
